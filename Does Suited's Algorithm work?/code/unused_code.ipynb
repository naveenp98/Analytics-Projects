# %%
final.loc[(final['Score'] == 0) & (final['Status'] == 'Rejected after 2nd Round') ,]
# Out:
#    First Name Last Name                  School  \
# 20       Anna  Campbell  London Business School
#
#                     Applicant Email                    Status  \
# 20  annacampbell@londonbusiness.edu  Rejected after 2nd Round
#
#     Behavioral Score  Critical Reasoning  Logical Reasoning  \
# 20          0.005707           64.830989          66.401589
#
#     Attention to Detail                     Suited Email     Degree  GPA  \
# 20            79.574965  annacampbell@londonbusiness.edu  Bachelors  3.7
#
#    GPA_binned  Logical Reasoning_binned  Critical Reasoning_binned  \
# 20       High                         0                          0
#
#     Attention to Detail_binned  Behavioral_binned  Score
# 20                           0                  0      0

# %%
final.loc[(final['Score'] == 1) & (final['Status'] == 'Received Job Offer') ,]
# Out:
#     First Name Last Name                                 School  \
# 32     Shirley     Davis               University of Notre Dame
# 54       Marie      King  University of California, Los Angeles
# 103      James    Taylor      Indiana University at Bloomington
# 111      David    Turner                     Fordham University
#
#              Applicant Email              Status  Behavioral Score  \
# 32      shirleydavis@und.edu  Received Job Offer          0.769591
# 54        marieking@ucla.edu  Received Job Offer          0.845230
# 103  jamestaylor@indiana.edu  Received Job Offer          0.157233
# 111  davidturner@fordham.edu  Received Job Offer          0.997315
#
#      Critical Reasoning  Logical Reasoning  Attention to Detail  \
# 32            41.276390          55.866533            73.460196
# 54            64.830989          55.866533            55.087972
# 103           78.276432          66.401589            73.460196
# ...

# %%
# How much did people who were rejected in the 1st round score?
pd.crosstab(final.loc[final['Status']=='Rejected after 1st Round', 'Status'], final.loc[final['Status']=='Rejected after 1st Round', 'Score']).plot(kind='barh', stacked=True, title="Distribution of candidate scores that were rejected at R1")
# Out:
# <AxesSubplot:title={'center':'Distribution of candidate scores that were rejected at R1'}, ylabel='Status'>
